# %% [markdown]
# <a href="https://colab.research.google.com/github/kirannair97/learning-python-2023/blob/main/P5_Math_Game_and_Rock_Paper_Scissor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project: Math Game & Rock-Paper-Scissor

# %% [markdown]
# ## Goal:
# 1.   Create a Math Game
# 2.   Create a Rock - Paper - Scissor Game

# %% [markdown]
# ### Math Game
# - First, import random
# - Get a random inteteger from the range 1 to 10 (both inclusive)
# - Get another random inteteger from the range 1 to 10 (both inclusive)
# - Prompt the user for what the two integers multiplied is
# - Print if correct or not. If not corrrect, print the correct answer.

# %%
import random
a = random.randint(1, 10)
b = random.randint(1, 10)
answer = input(f"What is {a} times {b}? ")
answer = int(answer)
if answer == a * b:
  print(f"Correct, {a} times {b} is {answer}")
else:
  print(f"Wrong answer, {a} times {b} is {a * b}")
# Out:
# What is 1 times 10? 10
# Correct, 1 times 10 is 10

# %% [markdown]
# ## Rock, Paper, Scissor Game

# %% [markdown]
# ![RockPaperScissors.png](data:image/png;base64,...)

# %%
print("Enter Choice: (1 : Rock), (2 : Paper), (3 : Scissor) ")
your_choice = input("Your Choice (1/2/3): ")
your_choice = int(your_choice)
computer_choice = random.randint(1, 3)
print(f"Computer Choice: {computer_choice}")

if your_choice == computer_choice:
  print("You Draw")
elif your_choice == 1:
  if computer_choice == 2:
    print("Computer Wins")
  else:
    print("You Win!")
elif your_choice == 2:
  if computer_choice == 3:
    print("Computer Wins")
  else:
    print("You Win!")
elif your_choice == 3:
  if computer_choice == 1:
    print("Computer Wins")
  else:
    print("You Win!")
# Out:
# Enter Choice: (1 : Rock), (2 : Paper), (3 : Scissor)
# Your Choice (1/2/3): 2
# Computer Choice: 2
# You Draw
